# %% [markdown]
# ## **Pandas**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('IBM Employee dataset.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 0     34      Travel_Rarely        790                   Sales
# 1     35      Travel_Rarely        660                   Sales
# 2     24  Travel_Frequently        381  Research & Development
# 3     24         Non-Travel        830                   Sales
# 4     44  Travel_Frequently       1193  Research & Development
# ..   ...                ...        ...                     ...
# 407   36  Travel_Frequently        884  Research & Development
# 408   39      Travel_Rarely        613  Research & Development
# 409   27      Travel_Rarely        155  Research & Development
# 410   49  Travel_Frequently       1023                   Sales
# 411   34      Travel_Rarely        628  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                  24          4        Medical              1
# 1                   7          1  Life Sciences              1
# ...

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   34      Travel_Rarely        790                   Sales
# 1   35      Travel_Rarely        660                   Sales
# 2   24  Travel_Frequently        381  Research & Development
# 3   24         Non-Travel        830                   Sales
# 4   44  Travel_Frequently       1193  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                24          4        Medical              1            1489
# 1                 7          1  Life Sciences              1            1492
# 2                 9          3        Medical              1            1494
# 3                13          2  Life Sciences              1            1495
# 4                 2          1        Medical              1            1496
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# ...

# %%
df.tail()
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 407   36  Travel_Frequently        884  Research & Development
# 408   39      Travel_Rarely        613  Research & Development
# 409   27      Travel_Rarely        155  Research & Development
# 410   49  Travel_Frequently       1023                   Sales
# 411   34      Travel_Rarely        628  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 407                23          2        Medical              1
# 408                 6          1        Medical              1
# 409                 4          3  Life Sciences              1
# 410                 2          3        Medical              1
# 411                 8          3        Medical              1
#
#      EmployeeNumber  EnvironmentSatisfaction  ... RelationshipSatisfaction  \
# 407            2061                        3  ...                        3
# ...

# %%
df.shape
# Out:
# (412, 34)

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       412 non-null    int64
#  1   BusinessTravel            412 non-null    object
#  2   DailyRate                 412 non-null    int64
#  3   Department                412 non-null    object
#  4   DistanceFromHome          412 non-null    int64
#  5   Education                 412 non-null    int64
#  6   EducationField            412 non-null    object
#  7   EmployeeCount             412 non-null    int64
#  8   EmployeeNumber            412 non-null    int64
#  9   EnvironmentSatisfaction   412 non-null    int64
#  10  Gender                    412 non-null    object
#  11  HourlyRate                412 non-null    int64
#  12  JobInvolvement            412 non-null    int64
#  13  JobLevel                  412 non-null    int64
# ...

# %%
df.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  412.000000   412.000000        412.000000  412.000000          412.0
# mean    36.584951   784.364078          9.742718    3.000000            1.0
# std      8.389257   390.361319          8.258996    1.001216            0.0
# min     18.000000   104.000000          1.000000    1.000000            1.0
# 25%     31.000000   464.750000          2.000000    2.000000            1.0
# 50%     35.500000   740.500000          8.000000    3.000000            1.0
# 75%     42.000000  1147.750000         15.000000    4.000000            1.0
# max     60.000000  1495.000000         29.000000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      412.000000               412.000000  412.000000      412.000000
# mean      1777.565534                 2.745146   66.526699        2.711165
# ...

# %%
df.nunique()
# Out:
# Age                          40
# BusinessTravel                3
# DailyRate                   354
# Department                    3
# DistanceFromHome             29
# Education                     5
# EducationField                6
# EmployeeCount                 1
# EmployeeNumber              412
# EnvironmentSatisfaction       4
# Gender                        2
# HourlyRate                   71
# JobInvolvement                4
# JobLevel                      5
# JobRole                       9
# JobSatisfaction               4
# MaritalStatus                 3
# MonthlyIncome               406
# MonthlyRate                 410
# NumCompaniesWorked           10
# Over18                        1
# OverTime                      2
# PercentSalaryHike            15
# PerformanceRating             2
# RelationshipSatisfaction      4
# StandardHours                 1
# StockOptionLevel              4
# TotalWorkingYears            36
# TrainingTimesLastYear         7
# ...

# %%
df.nunique()[0]
# Out:
# 40

# %% [markdown]
# ### **Pandas Series**

# %%
a = pd.Series([239.897, 378.09, 678.98, 345.65, 231.76, 543.09, 897.36])
print(a)
# Out:
# 0    239.897
# 1    378.090
# 2    678.980
# 3    345.650
# 4    231.760
# 5    543.090
# 6    897.360
# dtype: float64

# %%
a = pd.Series([23, 378, 67, 345, 231, 543, 897])
print(a)
# Out:
# 0     23
# 1    378
# 2     67
# 3    345
# 4    231
# 5    543
# 6    897
# dtype: int64

# %%
a.name = 'Daily Rate of Employees'
a
# Out:
# 0     23
# 1    378
# 2     67
# 3    345
# 4    231
# 5    543
# 6    897
# Name: Daily Rate of Employees, dtype: int64

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a.values
# Out:
# array([ 23, 378,  67, 345, 231, 543, 897], dtype=int64)

# %%
type(a.values)
# Out:
# numpy.ndarray

# %%
a[0]
# Out:
# 23

# %%
a[1]
# Out:
# 378

# %%
a.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
#we can define the index of series           (ordered elements)
a.index = [
    'Canada',
    'New York',
    'Germany',
    'Japan',
    'USA',
    'India',
    'China'
]

a
# Out:
# Canada       23
# New York    378
# Germany      67
# Japan       345
# USA         231
# India       543
# China       897
# Name: Daily Rate of Employees, dtype: int64

# %%
#creating series from a dictionary
pd.Series({
    'Canada' : 23,
    'New York' : 378,
    'Germany' : 67,
    'Japan' : 345,
    'USA' : 231,
    'India' : 543,
    'China' : 897
}, name = 'Daily Rate of Employees')
# Out:
# Canada       23
# New York    378
# Germany      67
# Japan       345
# USA         231
# India       543
# China       897
# Name: Daily Rate of Employees, dtype: int64

# %%
pd.Series(
    [ 23, 378,  67, 345, 231, 543, 897],
    index = ["Canada","New York","Germany","Japan","USA","India","China"],
    name = 'Daily rate of Employees'
)
# Out:
# Canada       23
# New York    378
# Germany      67
# Japan       345
# USA         231
# India       543
# China       897
# Name: Daily rate of Employees, dtype: int64

# %%
pd.Series(
    a,
    index = ["India","Japan","USA","Canada"]
)
# Out:
# India     543
# Japan     345
# USA       231
# Canada     23
# Name: Daily Rate of Employees, dtype: int64

# %%
certificates_earned = pd.Series(
    [8, 2, 5, 6],
    index=['Tom', 'Kris', 'Ahmad', 'Beau']
)

print(certificates_earned)
# Out:
# Tom      8
# Kris     2
# Ahmad    5
# Beau     6
# dtype: int64

# %% [markdown]
# ### **Indexing**

# %%
a
# Out:
# Canada       23
# New York    378
# Germany      67
# Japan       345
# USA         231
# India       543
# China       897
# Name: Daily Rate of Employees, dtype: int64

# %%
a['Canada']
# Out:
# 23

# %%
a['USA']
# Out:
# 231

# %% [markdown]
# ##### *Numeric positions can be used with iloc attribute*

# %%
a.iloc[0]
# Out:
# 23

# %%
a.iloc[-1]
# Out:
# 897

# %%
a[['Japan','India']]
# Out:
# Japan    345
# India    543
# Name: Daily Rate of Employees, dtype: int64

# %%
a.iloc[[2,-1]]
# Out:
# Germany     67
# China      897
# Name: Daily Rate of Employees, dtype: int64

# %% [markdown]
# ##### *Slicing (normally upper limited is exclusive) but in pandas, **upper limit is inclusive***

# %%
a['New York':'USA']
# Out:
# New York    378
# Germany      67
# Japan       345
# USA         231
# Name: Daily Rate of Employees, dtype: int64

# %% [markdown]
# #### **Conditional selection (Boolean arrays)**

# %%
a
# Out:
# Canada       23
# New York    378
# Germany      67
# Japan       345
# USA         231
# India       543
# China       897
# Name: Daily Rate of Employees, dtype: int64

# %%
a > 500
# Out:
# Canada      False
# New York    False
# Germany     False
# Japan       False
# USA         False
# India        True
# China        True
# Name: Daily Rate of Employees, dtype: bool

# %%
a [a > 500]
# Out:
# India    543
# China    897
# Name: Daily Rate of Employees, dtype: int64

# %%
a[(a > 500) | (a < 200)]
# Out:
# Canada      23
# Germany     67
# India      543
# China      897
# Name: Daily Rate of Employees, dtype: int64

# %%
a[(a > 500) & (a < 1000)]
# Out:
# India    543
# China    897
# Name: Daily Rate of Employees, dtype: int64

# %%
a.mean()
# Out:
# 354.85714285714283

# %%
a.std()
# Out:
# 299.5220796376724

# %%
a [a > a.mean()]
# Out:
# New York    378
# India       543
# China       897
# Name: Daily Rate of Employees, dtype: int64

# %%
a [a > a.mean() - a .std() / 2]
# Out:
# New York    378
# Japan       345
# USA         231
# India       543
# China       897
# Name: Daily Rate of Employees, dtype: int64

# %%
a [a > a.mean() + a .std() / 2]
# Out:
# India    543
# China    897
# Name: Daily Rate of Employees, dtype: int64

# %%
a[(a > a.mean() - a .std() / 2) | (a > a.mean() + a .std() / 2)]
# Out:
# New York    378
# Japan       345
# USA         231
# India       543
# China       897
# Name: Daily Rate of Employees, dtype: int64

# %% [markdown]
# #### **Operations and Methods**

# %%
a
# Out:
# Canada       23
# New York    378
# Germany      67
# Japan       345
# USA         231
# India       543
# China       897
# Name: Daily Rate of Employees, dtype: int64

# %%
a * 1_000_000   #OR  a * 1000000
# Out:
# Canada       23000000
# New York    378000000
# Germany      67000000
# Japan       345000000
# USA         231000000
# India       543000000
# China       897000000
# Name: Daily Rate of Employees, dtype: int64

# %%
a['Canada':'Germany']
# Out:
# Canada       23
# New York    378
# Germany      67
# Name: Daily Rate of Employees, dtype: int64

# %%
a['Canada':'Germany'].mean()
# Out:
# 156.0

# %%
np.log(a)
# Out:
# Canada      3.135494
# New York    5.934894
# Germany     4.204693
# Japan       5.843544
# USA         5.442418
# India       6.297109
# China       6.799056
# Name: Daily Rate of Employees, dtype: float64

# %% [markdown]
# #### **Modifying series**

# %%
a['Canada'] = 400.5
a
# Out:
# Canada      400.5
# New York    378.0
# Germany      67.0
# Japan       345.0
# USA         231.0
# India       543.0
# China       897.0
# Name: Daily Rate of Employees, dtype: float64

# %%
a.iloc[-1] = 860
a
# Out:
# Canada      400.5
# New York    378.0
# Germany      67.0
# Japan       345.0
# USA         231.0
# India       543.0
# China       860.0
# Name: Daily Rate of Employees, dtype: float64

# %%
a[a > 998]
# Out:
# Series([], Name: Daily Rate of Employees, dtype: float64)

# %%
a[a > 998] = 1000
a
# Out:
# Canada      400.5
# New York    378.0
# Germany      67.0
# Japan       345.0
# USA         231.0
# India       543.0
# China       860.0
# Name: Daily Rate of Employees, dtype: float64

# %% [markdown]
# ### **Pandas DataFrame**

# %% [markdown]
# #### *Creating Dataframe*

# %%
df = pd.DataFrame({
    'Population' : [621.9,893.67,235.9,123.78,569.8,453.9,976.2],
    'GDP' : [
        34556,
        282837,
        283325,
        148757,
        174755,
        399328,
        137337
    ],
    'Surface Area': [
        23467,
        34656,
        65343,
        78897,
        45767,
        89766,
        98673
    ],
    'HDI': [
        0.976,
        0.876,
        0.923,
        0.872,
        0.987,
        0.987,
        0.876
    ],
    'Continent': [
        'Asia',
        'Europe',
        'Africa',
        'Antartica',
        'France',
        'America',
        'Asia'
    ],
    'Language' : [
        'French',
        'German',
        'Italian'
    ]
}, columns = ['Population','GDP','Surface Area','HDI','Continent'])  #columns attribute is optional

# %%
df
# Out:
#    Population     GDP  Surface Area    HDI  Continent
# 0      621.90   34556         23467  0.976       Asia
# 1      893.67  282837         34656  0.876     Europe
# 2      235.90  283325         65343  0.923     Africa
# 3      123.78  148757         78897  0.872  Antartica
# 4      569.80  174755         45767  0.987     France
# 5      453.90  399328         89766  0.987    America
# 6      976.20  137337         98673  0.876       Asia

# %% [markdown]
# #### *we can assign index to dataframe*

# %%
df.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States'
]

# %%
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# Canada              621.90   34556         23467  0.976       Asia
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.info()   #gives info of structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %%
df.describe()   #gives summary statistics of dataframe only for numeric columns
# Out:
#        Population            GDP  Surface Area       HDI
# count    7.000000       7.000000      7.000000  7.000000
# mean   553.592857  208699.285714  62367.000000  0.928143
# std    314.850310  120808.703159  28599.527484  0.054520
# min    123.780000   34556.000000  23467.000000  0.872000
# 25%    344.900000  143047.000000  40211.500000  0.876000
# 50%    569.800000  174755.000000  65343.000000  0.923000
# 75%    757.785000  283081.000000  84331.500000  0.981500
# max    976.200000  399328.000000  98673.000000  0.987000

# %%
df.shape
# Out:
# (7, 5)

# %%
df.size
# Out:
# 35

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# Name: count, dtype: int64

# %% [markdown]
# ### **Indexing, Selection and Slicing**

# %%
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# Canada              621.90   34556         23467  0.976       Asia
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %%
#loc attribute selects individual rows and gives elements by index
df.loc['Canada']
# Out:
# Population      621.9
# GDP             34556
# Surface Area    23467
# HDI             0.976
# Continent        Asia
# Name: Canada, dtype: object

# %%
df.iloc[-1]  #iloc gives elements by position
# Out:
# Population       976.2
# GDP             137337
# Surface Area     98673
# HDI              0.876
# Continent         Asia
# Name: United States, dtype: object

# %%
df['Population']
# Out:
# Canada            621.90
# France            893.67
# Germany           235.90
# Italy             123.78
# Japan             569.80
# United Kingdom    453.90
# United States     976.20
# Name: Population, dtype: float64

# %%
df['Population'].to_frame()
# Out:
#                 Population
# Canada              621.90
# France              893.67
# Germany             235.90
# Italy               123.78
# Japan               569.80
# United Kingdom      453.90
# United States       976.20

# %%
df[['Population']]
# Out:
#                 Population
# Canada              621.90
# France              893.67
# Germany             235.90
# Italy               123.78
# Japan               569.80
# United Kingdom      453.90
# United States       976.20

# %%
df[['Population','GDP']]
# Out:
#                 Population     GDP
# Canada              621.90   34556
# France              893.67  282837
# Germany             235.90  283325
# Italy               123.78  148757
# Japan               569.80  174755
# United Kingdom      453.90  399328
# United States       976.20  137337

# %%
df[1:3]  #stop is exclusive
# Out:
#          Population     GDP  Surface Area    HDI Continent
# France       893.67  282837         34656  0.876    Europe
# Germany      235.90  283325         65343  0.923    Africa

# %%
df[0:3]
# Out:
#          Population     GDP  Surface Area    HDI Continent
# Canada       621.90   34556         23467  0.976      Asia
# France       893.67  282837         34656  0.876    Europe
# Germany      235.90  283325         65343  0.923    Africa

# %% [markdown]
# ##### *Row selection works better with loc and iloc than direct slicing df[:]*

# %%
#loc selects rows with given index
df.loc['Japan']
# Out:
# Population       569.8
# GDP             174755
# Surface Area     45767
# HDI              0.987
# Continent       France
# Name: Japan, dtype: object

# %%
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# Canada              621.90   34556         23467  0.976       Asia
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %%
df.loc['France' : 'Japan']  #stop is inclusive
# Out:
#          Population     GDP  Surface Area    HDI  Continent
# France       893.67  282837         34656  0.876     Europe
# Germany      235.90  283325         65343  0.923     Africa
# Italy        123.78  148757         78897  0.872  Antartica
# Japan        569.80  174755         45767  0.987     France

# %% [markdown]
# ##### *In the second argument you can pass the columns you want to select*

# %%
df.loc['France' : 'Japan', 'GDP']
# Out:
# France     282837
# Germany    283325
# Italy      148757
# Japan      174755
# Name: GDP, dtype: int64

# %%
df.loc['France' : 'Japan', ['GDP', 'HDI']]
# Out:
#             GDP    HDI
# France   282837  0.876
# Germany  283325  0.923
# Italy    148757  0.872
# Japan    174755  0.987

# %% [markdown]
# #### *iloc works with **numeric 'postion'** of index*

# %%
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# Canada              621.90   34556         23467  0.976       Asia
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %%
df.iloc[0]
# Out:
# Population      621.9
# GDP             34556
# Surface Area    23467
# HDI             0.976
# Continent        Asia
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       976.2
# GDP             137337
# Surface Area     98673
# HDI              0.876
# Continent         Asia
# Name: United States, dtype: object

# %%
df.iloc[1:3]  #stop is exclusive
# Out:
#          Population     GDP  Surface Area    HDI Continent
# France       893.67  282837         34656  0.876    Europe
# Germany      235.90  283325         65343  0.923    Africa

# %%
df.iloc[[0, 1, -1]]
# Out:
#                Population     GDP  Surface Area    HDI Continent
# Canada             621.90   34556         23467  0.976      Asia
# France             893.67  282837         34656  0.876    Europe
# United States      976.20  137337         98673  0.876      Asia

# %%
df.iloc[1:3, 1:3]  #1st argument for row slicing and 2nd argument for column slicing (stop is exclusive)
# Out:
#             GDP  Surface Area
# France   282837         34656
# Germany  283325         65343

# %%
df.iloc[1:3, 3]
# Out:
# France     0.876
# Germany    0.923
# Name: HDI, dtype: float64

# %%
df.iloc[1:3, [0,3]]
# Out:
#          Population    HDI
# France       893.67  0.876
# Germany      235.90  0.923

# %% [markdown]
# ##### **RECOMMENDED: Always use loc and iloc to reduce ambiguity, especially with DataFrames with numeric indexes**

# %%
certificates_earned = pd.DataFrame({
    'Certificates': [8, 2, 5, 6],
    'Time (in months)': [16, 5, 9, 12]
})
certificates_earned
# Out:
#    Certificates  Time (in months)
# 0             8                16
# 1             2                 5
# 2             5                 9
# 3             6                12

# %%
names = ['Tom', 'Kris', 'Ahmad', 'Beau']
certificates_earned.index = names
certificates_earned
# Out:
#        Certificates  Time (in months)
# Tom               8                16
# Kris              2                 5
# Ahmad             5                 9
# Beau              6                12

# %%
print(certificates_earned.iloc[2])
# Out:
# Certificates        5
# Time (in months)    9
# Name: Ahmad, dtype: int64

# %%
longest_streak = pd.Series([13,11,9,7], index = names)
longest_streak
# Out:
# Tom      13
# Kris     11
# Ahmad     9
# Beau      7
# dtype: int64

# %%
certificates_earned['Longest streak'] = longest_streak
certificates_earned
# Out:
#        Certificates  Time (in months)  Longest streak
# Tom               8                16              13
# Kris              2                 5              11
# Ahmad             5                 9               9
# Beau              6                12               7

# %% [markdown]
# ### **Conditional selection (boolean arrays)**

# %%
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# Canada              621.90   34556         23467  0.976       Asia
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %%
df['Population'] > 500
# Out:
# Canada             True
# France             True
# Germany           False
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %%
df.loc[df['Population'] > 500]
# Out:
#                Population     GDP  Surface Area    HDI Continent
# Canada             621.90   34556         23467  0.976      Asia
# France             893.67  282837         34656  0.876    Europe
# Japan              569.80  174755         45767  0.987    France
# United States      976.20  137337         98673  0.876      Asia

# %%
df.loc[df['Population'] > 500, 'Population']
# Out:
# Canada           621.90
# France           893.67
# Japan            569.80
# United States    976.20
# Name: Population, dtype: float64

# %%
df.loc[df['Population'] > 500, ['Population','GDP']]
# Out:
#                Population     GDP
# Canada             621.90   34556
# France             893.67  282837
# Japan              569.80  174755
# United States      976.20  137337

# %% [markdown]
# #### **Dropping stuff**

# %%
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# Canada              621.90   34556         23467  0.976       Asia
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %%
df.drop('Canada')
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %%
df.drop(['Canada','Japan'])
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %%
df.drop(columns=['Population','HDI'])    #dropping columns
# Out:
#                    GDP  Surface Area  Continent
# Canada           34556         23467       Asia
# France          282837         34656     Europe
# Germany         283325         65343     Africa
# Italy           148757         78897  Antartica
# Japan           174755         45767     France
# United Kingdom  399328         89766    America
# United States   137337         98673       Asia

# %%
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# Canada              621.90   34556         23467  0.976       Asia
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %%
df.drop(['Italy','Canada'], axis = 0)  #axis = 0 for rows
# Out:
#                 Population     GDP  Surface Area    HDI Continent
# France              893.67  282837         34656  0.876    Europe
# Germany             235.90  283325         65343  0.923    Africa
# Japan               569.80  174755         45767  0.987    France
# United Kingdom      453.90  399328         89766  0.987   America
# United States       976.20  137337         98673  0.876      Asia

# %%
df.drop(['Italy','Canada'], axis = 'rows')
# Out:
#                 Population     GDP  Surface Area    HDI Continent
# France              893.67  282837         34656  0.876    Europe
# Germany             235.90  283325         65343  0.923    Africa
# Japan               569.80  174755         45767  0.987    France
# United Kingdom      453.90  399328         89766  0.987   America
# United States       976.20  137337         98673  0.876      Asia

# %%
df.drop(['Population', 'GDP'], axis = 1)  #axis = 1 for columns
# Out:
#                 Surface Area    HDI  Continent
# Canada                 23467  0.976       Asia
# France                 34656  0.876     Europe
# Germany                65343  0.923     Africa
# Italy                  78897  0.872  Antartica
# Japan                  45767  0.987     France
# United Kingdom         89766  0.987    America
# United States          98673  0.876       Asia

# %%
df.drop(['Population', 'GDP'], axis = 'columns')
# Out:
#                 Surface Area    HDI  Continent
# Canada                 23467  0.976       Asia
# France                 34656  0.876     Europe
# Germany                65343  0.923     Africa
# Italy                  78897  0.872  Antartica
# Japan                  45767  0.987     France
# United Kingdom         89766  0.987    America
# United States          98673  0.876       Asia

# %% [markdown]
# ### **Operations**

# %%
df[['Population','GDP']]
# Out:
#                 Population     GDP
# Canada              621.90   34556
# France              893.67  282837
# Germany             235.90  283325
# Italy               123.78  148757
# Japan               569.80  174755
# United Kingdom      453.90  399328
# United States       976.20  137337

# %%
df[['Population','GDP']] / 100
# Out:
#                 Population      GDP
# Canada              6.2190   345.56
# France              8.9367  2828.37
# Germany             2.3590  2833.25
# Italy               1.2378  1487.57
# Japan               5.6980  1747.55
# United Kingdom      4.5390  3993.28
# United States       9.7620  1373.37

# %%
#broadcasting with series
crises = pd.Series([-1_000_000, -0.3], index = ['GDP','HDI'])
crises
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP','HDI']] + crises
# Out:
#                      GDP    HDI
# Canada         -965444.0  0.676
# France         -717163.0  0.576
# Germany        -716675.0  0.623
# Italy          -851243.0  0.572
# Japan          -825245.0  0.687
# United Kingdom -600672.0  0.687
# United States  -862663.0  0.576

# %% [markdown]
# ### **Modifying DataFrames**

# %% [markdown]
# #### *we can add columns or replace values for columns*

# %% [markdown]
# #### **Adding a new column**

# %%
lang = pd.Series(
    ['French','Italian','German'],
    index = ['France','Italy','Germany'],
    name = 'Language'
)
lang
# Out:
# France      French
# Italy      Italian
# Germany     German
# Name: Language, dtype: object

# %%
df['Language'] = lang

# %%
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent Language
# Canada              621.90   34556         23467  0.976       Asia      NaN
# France              893.67  282837         34656  0.876     Europe   French
# Germany             235.90  283325         65343  0.923     Africa   German
# Italy               123.78  148757         78897  0.872  Antartica  Italian
# Japan               569.80  174755         45767  0.987     France      NaN
# United Kingdom      453.90  399328         89766  0.987    America      NaN
# United States       976.20  137337         98673  0.876       Asia      NaN

# %% [markdown]
# #### **Replacing values per column**

# %%
df['Language'] = 'English'
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent Language
# Canada              621.90   34556         23467  0.976       Asia  English
# France              893.67  282837         34656  0.876     Europe  English
# Germany             235.90  283325         65343  0.923     Africa  English
# Italy               123.78  148757         78897  0.872  Antartica  English
# Japan               569.80  174755         45767  0.987     France  English
# United Kingdom      453.90  399328         89766  0.987    America  English
# United States       976.20  137337         98673  0.876       Asia  English

# %% [markdown]
# #### **Renaming columns**

# %%
df.rename(
    columns = {
        'HDI' : 'Human Development Index',
        'Annual Popcorn Consumption' : 'APC'
    }, index = {
        'United States' : 'USA',
        'United Kingdom' : 'UK',
        'Argentina' : 'AR'       #APC and Argentia doesn't exist in a data frame but that doesn't caiuse a problem
    }
)
# Out:
#          Population     GDP  Surface Area  Human Development Index  Continent  \
# Canada       621.90   34556         23467                    0.976       Asia
# France       893.67  282837         34656                    0.876     Europe
# Germany      235.90  283325         65343                    0.923     Africa
# Italy        123.78  148757         78897                    0.872  Antartica
# Japan        569.80  174755         45767                    0.987     France
# UK           453.90  399328         89766                    0.987    America
# USA          976.20  137337         98673                    0.876       Asia
#
#         Language
# Canada   English
# France   English
# Germany  English
# Italy    English
# Japan    English
# UK       English
# USA      English

# %%
df   #original DataFrame hasn't changed
# Out:
#                 Population     GDP  Surface Area    HDI  Continent Language
# Canada              621.90   34556         23467  0.976       Asia  English
# France              893.67  282837         34656  0.876     Europe  English
# Germany             235.90  283325         65343  0.923     Africa  English
# Italy               123.78  148757         78897  0.872  Antartica  English
# Japan               569.80  174755         45767  0.987     France  English
# United Kingdom      453.90  399328         89766  0.987    America  English
# United States       976.20  137337         98673  0.876       Asia  English

# %%
df.rename(index = str.upper)
# Out:
#                 Population     GDP  Surface Area    HDI  Continent Language
# CANADA              621.90   34556         23467  0.976       Asia  English
# FRANCE              893.67  282837         34656  0.876     Europe  English
# GERMANY             235.90  283325         65343  0.923     Africa  English
# ITALY               123.78  148757         78897  0.872  Antartica  English
# JAPAN               569.80  174755         45767  0.987     France  English
# UNITED KINGDOM      453.90  399328         89766  0.987    America  English
# UNITED STATES       976.20  137337         98673  0.876       Asia  English

# %%
df.rename(index = lambda x : x.lower())
# Out:
#                 Population     GDP  Surface Area    HDI  Continent Language
# canada              621.90   34556         23467  0.976       Asia  English
# france              893.67  282837         34656  0.876     Europe  English
# germany             235.90  283325         65343  0.923     Africa  English
# italy               123.78  148757         78897  0.872  Antartica  English
# japan               569.80  174755         45767  0.987     France  English
# united kingdom      453.90  399328         89766  0.987    America  English
# united states       976.20  137337         98673  0.876       Asia  English

# %%
df.rename(index = str.lower)
# Out:
#                 Population     GDP  Surface Area    HDI  Continent Language
# canada              621.90   34556         23467  0.976       Asia  English
# france              893.67  282837         34656  0.876     Europe  English
# germany             235.90  283325         65343  0.923     Africa  English
# italy               123.78  148757         78897  0.872  Antartica  English
# japan               569.80  174755         45767  0.987     France  English
# united kingdom      453.90  399328         89766  0.987    America  English
# united states       976.20  137337         98673  0.876       Asia  English

# %% [markdown]
# #### **Dropping columns**

# %%
df.drop(columns = 'Language', inplace = True)
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent
# Canada              621.90   34556         23467  0.976       Asia
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia

# %% [markdown]
# #### **More radical index changes**

# %%
df.reset_index()
# Out:
#             index  Population     GDP  Surface Area    HDI  Continent
# 0          Canada      621.90   34556         23467  0.976       Asia
# 1          France      893.67  282837         34656  0.876     Europe
# 2         Germany      235.90  283325         65343  0.923     Africa
# 3           Italy      123.78  148757         78897  0.872  Antartica
# 4           Japan      569.80  174755         45767  0.987     France
# 5  United Kingdom      453.90  399328         89766  0.987    America
# 6   United States      976.20  137337         98673  0.876       Asia

# %%
df.set_index('Population')
# Out:
#                GDP  Surface Area    HDI  Continent
# Population
# 621.90       34556         23467  0.976       Asia
# 893.67      282837         34656  0.876     Europe
# 235.90      283325         65343  0.923     Africa
# 123.78      148757         78897  0.872  Antartica
# 569.80      174755         45767  0.987     France
# 453.90      399328         89766  0.987    America
# 976.20      137337         98673  0.876       Asia

# %% [markdown]
# ### **Creating columns from other columns**

# %%
df[['Population', 'GDP']]
# Out:
#                 Population     GDP
# Canada              621.90   34556
# France              893.67  282837
# Germany             235.90  283325
# Italy               123.78  148757
# Japan               569.80  174755
# United Kingdom      453.90  399328
# United States       976.20  137337

# %%
df['GDP'] / df['Population']
# Out:
# Canada              55.565203
# France             316.489308
# Germany           1201.038576
# Italy             1201.785426
# Japan              306.695332
# United Kingdom     879.770875
# United States      140.685310
# dtype: float64

# %% [markdown]
# #### *The result of this operation is another series which we can add to **original DataFrame***

# %%
df['GDP Per Capita'] = df['GDP'] / df['Population']

# %%
df
# Out:
#                 Population     GDP  Surface Area    HDI  Continent  \
# Canada              621.90   34556         23467  0.976       Asia
# France              893.67  282837         34656  0.876     Europe
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia
#
#                 GDP Per Capita
# Canada               55.565203
# France              316.489308
# Germany            1201.038576
# Italy              1201.785426
# Japan               306.695332
# United Kingdom      879.770875
# United States       140.685310

# %% [markdown]
# ### **Statistical info**

# %%
df.describe()
# Out:
#        Population            GDP  Surface Area       HDI  GDP Per Capita
# count    7.000000       7.000000      7.000000  7.000000        7.000000
# mean   553.592857  208699.285714  62367.000000  0.928143      586.004290
# std    314.850310  120808.703159  28599.527484  0.054520      495.660977
# min    123.780000   34556.000000  23467.000000  0.872000       55.565203
# 25%    344.900000  143047.000000  40211.500000  0.876000      223.690321
# 50%    569.800000  174755.000000  65343.000000  0.923000      316.489308
# 75%    757.785000  283081.000000  84331.500000  0.981500     1040.404725
# max    976.200000  399328.000000  98673.000000  0.987000     1201.785426

# %%
df.head()
# Out:
#          Population     GDP  Surface Area    HDI  Continent  GDP Per Capita
# Canada       621.90   34556         23467  0.976       Asia       55.565203
# France       893.67  282837         34656  0.876     Europe      316.489308
# Germany      235.90  283325         65343  0.923     Africa     1201.038576
# Italy        123.78  148757         78897  0.872  Antartica     1201.785426
# Japan        569.80  174755         45767  0.987     France      306.695332

# %%
df.tail()
# Out:
#                 Population     GDP  Surface Area    HDI  Continent  \
# Germany             235.90  283325         65343  0.923     Africa
# Italy               123.78  148757         78897  0.872  Antartica
# Japan               569.80  174755         45767  0.987     France
# United Kingdom      453.90  399328         89766  0.987    America
# United States       976.20  137337         98673  0.876       Asia
#
#                 GDP Per Capita
# Germany            1201.038576
# Italy              1201.785426
# Japan               306.695332
# United Kingdom      879.770875
# United States       140.685310

# %%
population = df['Population']

# %%
population.min(), population.max()
# Out:
# (123.78, 976.2)

# %%
population.sum()
# Out:
# 3875.1500000000005

# %%
population.sum() / len(population)  #Mean
# Out:
# 553.5928571428573

# %%
population.mean()
# Out:
# 553.5928571428573

# %%
population.std()
# Out:
# 314.8503101853475

# %%
population.median()   #50%
# Out:
# 569.8

# %%
population.quantile(.25)
# Out:
# 344.9

# %%
population.quantile([.2, .4, .6, .8, 1])
# Out:
# 0.2    279.500
# 0.4    500.260
# 0.6    601.060
# 0.8    839.316
# 1.0    976.200
# Name: Population, dtype: float64

# %% [markdown]
# ### **Reading external data and plotting**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# #### *Pandas can easily read data stored in diff file formats such as CSV, Excel, JSON, XML. The read_csv reads CSV file and accepts many parameters (pandas.read_csv)*

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols=None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace: 'bool' = False,
#     skiprows=None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values=None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool' = False,
#     skip_blank_lines: 'bool' = True,
#     parse_dates: 'bool | Sequence[Hashable] | None' = None,
# ...

# %% [markdown]
# #### *pandas automatically assigns the first row of data as headers, we can overwrite it using the header parameter*

# %%
df = pd.read_csv('btc-market-price.csv')

# %%
df.head()
# Out:
#    15-09-2023  08:00:00
# 0  16-09-2023  09:00:00
# 1  17-09-2023  10:00:00
# 2  18-09-2023  11:00:00
# 3  19-09-2023  12:00:00
# 4  20-09-2023  13:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   15-09-2023  646 non-null    object
#  1   08:00:00    646 non-null    object
# dtypes: object(2)
# memory usage: 10.2+ KB

# %%
df =pd.read_csv('btc-market-price.csv', header = None)
df
# Out:
#               0         1
# 0    15-09-2023  08:00:00
# 1    16-09-2023  09:00:00
# 2    17-09-2023  10:00:00
# 3    18-09-2023  11:00:00
# 4    19-09-2023  12:00:00
# ..          ...       ...
# 642  18-06-2025  02:00:00
# 643  19-06-2025  03:00:00
# 644  20-06-2025  04:00:00
# 645  21-06-2025  05:00:00
# 646  22-06-2025  06:00:00
#
# [647 rows x 2 columns]

# %% [markdown]
# #### *We can set the names of each columns by setting the df.columns attribute*

# %%
df.columns = ['Timestamp','Price']
df
# Out:
#       Timestamp     Price
# 0    15-09-2023  08:00:00
# 1    16-09-2023  09:00:00
# 2    17-09-2023  10:00:00
# 3    18-09-2023  11:00:00
# 4    19-09-2023  12:00:00
# ..          ...       ...
# 642  18-06-2025  02:00:00
# 643  19-06-2025  03:00:00
# 644  20-06-2025  04:00:00
# 645  21-06-2025  05:00:00
# 646  22-06-2025  06:00:00
#
# [647 rows x 2 columns]

# %%
df.head()
# Out:
#     Timestamp     Price
# 0  15-09-2023  08:00:00
# 1  16-09-2023  09:00:00
# 2  17-09-2023  10:00:00
# 3  18-09-2023  11:00:00
# 4  19-09-2023  12:00:00

# %%
df.tail()
# Out:
#       Timestamp     Price
# 642  18-06-2025  02:00:00
# 643  19-06-2025  03:00:00
# 644  20-06-2025  04:00:00
# 645  21-06-2025  05:00:00
# 646  22-06-2025  06:00:00

# %%
df.head(2)
# Out:
#     Timestamp     Price
# 0  15-09-2023  08:00:00
# 1  16-09-2023  09:00:00

# %%
df.tail(3)
# Out:
#       Timestamp     Price
# 644  20-06-2025  04:00:00
# 645  21-06-2025  05:00:00
# 646  22-06-2025  06:00:00

# %%
df.shape
# Out:
# (647, 2)

# %%
df.dtypes
# Out:
# Timestamp    object
# Price        object
# dtype: object

# %%
pd.to_datetime(df['Timestamp']).head()
# Out:
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_5604\1027740461.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(df['Timestamp']).head()
# 0   2023-09-15
# 1   2023-09-16
# 2   2023-09-17
# 3   2023-09-18
# 4   2023-09-19
# Name: Timestamp, dtype: datetime64[ns]

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp']).head()
# Out:
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_5604\1903206160.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Timestamp'] = pd.to_datetime(df['Timestamp']).head()

# %%
df.dtypes
# Out:
# Timestamp    datetime64[ns]
# Price                object
# dtype: object

# %%
#setting index of dataframe as timestamp
df.set_index('Timestamp', inplace = True)

# %%
df.head()
# Out:
#                Price
# Timestamp
# 2023-09-15  08:00:00
# 2023-09-16  09:00:00
# 2023-09-17  10:00:00
# 2023-09-18  11:00:00
# 2023-09-19  12:00:00

# %%
df.loc['2023-09-18']
# Out:
# Price    11:00:00
# Name: 2023-09-18 00:00:00, dtype: object

# %% [markdown]
# ### **Putting everything together**

# %%
df = pd.read_csv('btc-market-price.csv')
df.columns = ['Timestamp','Price']
df['Timestamp'] = pd.to_datetime(df['Timestamp']).head()
df.set_index('Timestamp', inplace = True)
# Out:
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_2672\3225906839.py:3: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Timestamp'] = pd.to_datetime(df['Timestamp']).head()

# %%
df.head()
# Out:
#                Price
# Timestamp
# 2023-09-16  09:00:00
# 2023-09-17  10:00:00
# 2023-09-18  11:00:00
# 2023-09-19  12:00:00
# 2023-09-20  13:00:00

# %% [markdown]
# #### *read_csv method is extermemly powerful, you can specify more parameteres at import time*

# %%
df = pd.read_csv(
    'btc-market-price.csv',         #read the csv
    header = None,                  #don't assign a header
    names = ['Timestamp','Price'],  #assign column names
    index_col = 0,                  #1st column will be the index of dataframe
    parse_dates = True
)
# Out:
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_5604\1023226827.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv(

# %%
df.head()
# Out:
#                Price
# Timestamp
# 2023-09-15  08:00:00
# 2023-09-16  09:00:00
# 2023-09-17  10:00:00
# 2023-09-18  11:00:00
# 2023-09-19  12:00:00

# %% [markdown]
# #### **Plotting basics**

# %%
df = pd.read_csv('task1\california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# #### *Panda integrates with Matplotlib and created plots*

# %%
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ##### *BTS its using matplotlib.pylot interface. we can create a similar plot usingh plt.plot() function*

# %%
plt.plot(df.index, df[['median_income']])

# %% [markdown]
# ##### *plt.plot accepts many parametres but the first two parameters are the values X and Y axis*

# %%
x = np.arange(-10,11)

# %%
plt.plot(x, x**2)

# %%
plt.plot(x, x **2)
plt.plot(x, -1 * (x ** 2))

# %%
plt.figure(figsize=(12, 6))   #to fix the size

plt.plot(x, x ** 2)
plt.plot(x, -1 * (x ** 2))

plt.title('My Nice Plot')   #to set the title
# Out:
# Text(0.5, 1.0, 'My Nice Plot')

# %%
df.plot(figsize = (16,9), title = 'Bitcoin Price 2022-2023')
# Out:
# <Axes: title={'center': 'Bitcoin Price 2022-2023'}>

# %% [markdown]
# ### **Data Cleaning**

# %% [markdown]
# ### **Handling Missing Data with Pandas**

# %% [markdown]
# #### **Pandas utility functions**

# %% [markdown]
# ##### Similarly to numpy, pandas also has a few utility functions to identify and detect null values such as pd.isnull(), pd.isna(), pd.notnull(), pd.notna()

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
pd.isnull(None)
# Out:
# True

# %% [markdown]
# ##### isnull() an isna() are synonymous i.e for Pandas they are same

# %%
pd.isna(np.nan)
# Out:
# True

# %%
pd.isna(None)
# Out:
# True

# %% [markdown]
# ##### The opposite ones also exits

# %%
pd.notnull(None)
# Out:
# False

# %%
pd.notnull(np.nan)
# Out:
# False

# %%
pd.notna(np.nan)
# Out:
# False

# %%
pd.notna(None)
# Out:
# False

# %%
pd.notnull(3)
# Out:
# True

# %%
pd.notna(1)
# Out:
# True

# %% [markdown]
# ##### This functions also work with Series and DataFrames

# %%
pd.isnull(pd.Series([3, np.nan, 7]))
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
pd.notnull(pd.Series([3, np.nan, 7]))
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
pd.isnull(pd.DataFrame({
    'Column A' : [3, np.nan, 7],
    'Column B' : [np.nan, 2, 3],
    'Column C' : [np.nan, np.nan, 2] 
}))
# Out:
#    Column A  Column B  Column C
# 0     False      True      True
# 1      True     False      True
# 2     False     False     False

# %% [markdown]
# ### **Pandas operations with missing values**

# %% [markdown]
# ##### Pandas manages missing values more gracefully than numpy. nans will no longer behave as "viruses", and operations will just ignore them completely

# %%
pd.Series([1, 2, np.nan]).count()
# Out:
# 2

# %%
pd.Series([1, 2, np.nan]).mean()
# Out:
# 1.5

# %%
pd.Series([1, 2, np.nan]).sum()
# Out:
# 3.0

# %% [markdown]
# ### **Filtering missing data**

# %%
a = pd.Series([1, 2, 3, np.nan, np.nan, 4])

# %%
pd.notnull(a)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
pd.notnull(a).count()
# Out:
# 6

# %%
pd.notnull(a).sum()  #gets no. of non-null values because its dtype is boolean so every True value is considered as 1 and False value as 0
# Out:
# 4

# %%
pd.isnull(a).sum()  #gets no. of null values
# Out:
# 2

# %%
a[pd.notnull(a)]
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 5    4.0
# dtype: float64

# %% [markdown]
# ##### notnull and isnull are methods of both Series and DatFrames

# %%
a.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
a.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
a[a.notnull()]
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 5    4.0
# dtype: float64

# %%
b = pd.Series(['a', 3, np.nan, 1, np.nan])

# %%
b.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
b = pd.Series(['a', 3, np.nan, 1, np.nan])

# %%
b.notnull().sum()
# Out:
# 3

# %% [markdown]
# ### **Dropping null values**

# %% [markdown]
# ##### Boolean selection + notnull() seems a little bit verbose and repetitive. And as we said before: any repetitive task will probably have a better, more DRY way. In this case, we can use the dropna()

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %%
a.dropna()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 5    4.0
# dtype: float64

# %% [markdown]
# ##### All this methods are immutable. We are not actually changing/ modifying the original series. There is a new which is created are returned.

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %% [markdown]
# ### **Dropping null values on DataFrames**

# %% [markdown]
# ##### You saw how simple it is to drop na with a Series. But with DataFrames, there will be a few more things to consider, because you can't drop single values. You can only drop entire columns or rows.

# %%
df = pd.DataFrame({
    'Column A' : [1, np.nan, 30, np.nan],
    'Column B' : [2, 8, 31, np.nan],
    'Column C' : [np.nan, 9, 32, 100],
    'Column D' : [5, 8, 34, 110]
})
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column A  2 non-null      float64
#  1   Column B  3 non-null      float64
#  2   Column C  3 non-null      float64
#  3   Column D  4 non-null      int64
# dtypes: float64(3), int64(1)
# memory usage: 260.0 bytes

# %%
df.shape
# Out:
# (4, 4)

# %%
df.isnull()
# Out:
#    Column A  Column B  Column C  Column D
# 0     False     False      True     False
# 1      True     False     False     False
# 2     False     False     False     False
# 3      True      True     False     False

# %%
df.isnull().sum()
# Out:
# Column A    2
# Column B    1
# Column C    1
# Column D    0
# dtype: int64

# %% [markdown]
# ##### The default **dropna** behavior will drop all the rows in which any null value is present

# %%
df.dropna()
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %% [markdown]
# ##### In this case we're dropping **rows**. Rows containing null values are dropped from the DF. You can also use the **axis** parameter to drop columns containing null values

# %%
df.dropna(axis = 1)   #axis = 1 for columns #axis='columns' also works
# Out:
#    Column D
# 0         5
# 1         8
# 2        34
# 3       110

# %%
df.dropna(axis = 'columns')
# Out:
#    Column D
# 0         5
# 1         8
# 2        34
# 3       110

# %%
df.dropna(axis = 0)  #default axis = 0 for rows #axis = 'rows' also works
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %%
df.dropna(axis = 'rows')
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %% [markdown]
# ##### Any row or column that contains at least one null value will be dropped. Which can be, depending on the case, too extreme. You can control this behavior with the **how** parameter. Can be either **'any'** or **'all'**

# %%
df2 = pd.DataFrame({
    'Column A': [1, np.nan, 30],
    'Column B': [2, np.nan, 31],
    'Column C': [np.nan, np.nan, 100]
})
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.dropna(how = 'all')
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.dropna(how = 'any')    #default behavior
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %% [markdown]
# ##### You can also use the thresh parameter to indicate a threshold (a minimum number) of non-null values for the row/column to be kept

# %%
df.dropna(thresh = 3)  #by default rows
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34

# %%
df.dropna(thresh = 3, axis = 'columns')
# Out:
#    Column B  Column C  Column D
# 0       2.0       NaN         5
# 1       8.0       9.0         8
# 2      31.0      32.0        34
# 3       NaN     100.0       110

# %% [markdown]
# ### **Filling  null values**

# %% [markdown]
# ##### Sometimes instead of dropping the null values, we might need to replace them with some other value. This highly depends on your context and the dataset you're currently working. Sometimes a **nan** can be replaced with a **0**, sometimes it can be replaced with the **mean** of the sample, and some other times you can take the closest value.

# %% [markdown]
# ##### **Filling nulls with a arbitrary value**

# %%
a.fillna(0)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    0.0
# 4    0.0
# 5    4.0
# dtype: float64

# %%
a.fillna(a.mean())
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    2.5
# 4    2.5
# 5    4.0
# dtype: float64

# %%
a    #original series is not changing
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %% [markdown]
# ##### **filling null values with contiguous (close) values**

# %% [markdown]
# ##### The method argument is used to fill null values with other values close to that null one. method argument has 2 types : ffill  (forward fill) and bfill (backward fill)

# %%
a.fillna(method = 'ffill')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# 4    3.0
# 5    4.0
# dtype: float64

# %%
a.fillna(method = 'bfill')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    4.0
# 5    4.0
# dtype: float64

# %% [markdown]
# ##### This can still leave null values at the extremes of the Series/DataFrame

# %%
pd.Series([np.nan, 3, np.nan, 9]). fillna(method = 'ffill')
# Out:
# 0    NaN
# 1    3.0
# 2    3.0
# 3    9.0
# dtype: float64

# %%
pd.Series([np.nan, 1, 3, np.nan]). fillna(method = 'bfill')
# Out:
# 0    1.0
# 1    1.0
# 2    3.0
# 3    NaN
# dtype: float64

# %% [markdown]
# ### **Filling null values on DataFrames**

# %% [markdown]
# ##### The **fillna** method also works on **DataFrames**, and it works similarly. The main differences are that you can specify the **axis** (as usual, rows or columns) to fill the values.

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.fillna({
    'Column A' : 0,
    'Column B' : 99,
    'Column C' : df['Column C'].mean()
})
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0      47.0         5
# 1       0.0       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       0.0      99.0     100.0       110

# %%
df.fillna(method = 'ffill', axis = 0)  #axis = 0 for columns
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       1.0       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3      30.0      31.0     100.0       110

# %%
df.fillna(method = 'ffill', axis = 1)  #axis = 1 for rows
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       2.0       5.0
# 1       NaN       8.0       9.0       8.0
# 2      30.0      31.0      32.0      34.0
# 3       NaN       NaN     100.0     110.0

# %%
df.fillna(method = 'bfill', axis = 0)  #axis = 0 for columns
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       9.0         5
# 1      30.0       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.fillna(method = 'bfill', axis = 1)  #axis = 1 for rows
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       5.0       5.0
# 1       8.0       8.0       9.0       8.0
# 2      30.0      31.0      32.0      34.0
# 3     100.0     100.0     100.0     110.0

# %% [markdown]
# #### **Checking if there are NAs**

# %% [markdown]
# #### The question is: Does this **Series** or **DataFrame** contain any missing value? The answer should be yes or no: **True** or **False**. How can you verify it?

# %% [markdown]
# ##### **Example 1: Checking the length**

# %% [markdown]
# ##### If there are missing values, **a.dropna()** will have less elements than **a**

# %%
a.dropna().count()
# Out:
# 4

# %%
missing_values = len(a.dropna()) != len(a)
missing_values
# Out:
# True

# %% [markdown]
# ##### There's also a **count** method, that excludes **nan**s from its result

# %%
len(a)
# Out:
# 6

# %%
a.count()
# Out:
# 4

# %%
missing_values = a.count() != len(a)
missing_values
# Out:
# True

# %% [markdown]
# #### **More Pythonic solution `any`**

# %% [markdown]
# ##### The methods `any` and `all` check if either there's `any` True value in a Series or `all` the values are `True`. They work in the same way as in Python.

# %%
pd.Series([True, False, False]).any()  #checks if any value is True, if yes returns True else False
# Out:
# True

# %%
pd.Series([True, False, False]).all()   #checks if all values are True, if yes returns True else False
# Out:
# False

# %%
pd.Series([True, True, True]).all()
# Out:
# True

# %% [markdown]
# ##### The `isnull()` method returned a Boolean `Series` with `True` values wherever there was a `nan`

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %%
a.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %% [markdown]
# ##### So we can just use the `any` method with the boolean array returned

# %%
pd.Series([1, np.nan])
# Out:
# 0    1.0
# 1    NaN
# dtype: float64

# %%
pd.Series([1, np.nan]).isnull().any()
# Out:
# True

# %%
pd.Series([1, 2])
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
pd.Series([1, 2]).isnull().any()
# Out:
# False

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %%
a.isnull().any()
# Out:
# True

# %% [markdown]
# ##### A more strict version would check only the `values` of the Series

# %%
a.isnull().values
# Out:
# array([False, False, False,  True,  True, False])

# %%
a.isnull().values.any()
# Out:
# True

# %% [markdown]
# ### **Cleaning not-null values**

# %%
df = pd.DataFrame({
    'Sex' : ['M','F','F','D','?'],
    'Age' : [20, 19, 34, 290, 25]
})
df
# Out:
#   Sex  Age
# 0   M   20
# 1   F   19
# 2   F   34
# 3   D  290
# 4   ?   25

# %%
df['Sex'].unique()
# Out:
# array(['M', 'F', 'D', '?'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# F    2
# M    1
# D    1
# ?    1
# Name: count, dtype: int64

# %%
df.replace('D','F')  #replace(which_value_to_replace, by_which_to_replace)
# Out:
#   Sex  Age
# 0   M   20
# 1   F   19
# 2   F   34
# 3   F  290
# 4   ?   25

# %%
df.replace({
    'D' : 'F',
    'N' : 'M'
})
# Out:
#   Sex  Age
# 0   M   20
# 1   F   19
# 2   F   34
# 3   F  290
# 4   ?   25

# %%
df.replace({
    'Sex' : {
        'D' : 'F',
        'N' : 'M'
    },
    'Age' : {
        290 : 29
    }
})
# Out:
#   Sex  Age
# 0   M   20
# 1   F   19
# 2   F   34
# 3   F   29
# 4   ?   25

# %%
df[df['Age'] > 100]
# Out:
#   Sex  Age
# 3   D  290

# %%
df.loc[df['Age'] > 100, 'Age'] = df.loc[df['Age'] > 100, 'Age'] / 10 
df
# Out:
#   Sex  Age
# 0   M   20
# 1   F   19
# 2   F   34
# 3   D   29
# 4   ?   25

# %% [markdown]
# #### **Duplicates**

# %%
ambassadors = pd.Series([
    'France',
    'United Kingdom',
    'United Kingdom',
    'Italy',
    'Germany',
    'Germany',
    'Germany'
], index = [
    'Gérard Araud',
    'Kim Darroch',
    'Peter Westmacott',
    'Armando Varricchio',
    'Peter Wittig',
    'Peter Ammon',
    'Klaus Scharioth'
])
ambassadors
# Out:
# Gérard Araud                  France
# Kim Darroch           United Kingdom
# Peter Westmacott      United Kingdom
# Armando Varricchio             Italy
# Peter Wittig                 Germany
# Peter Ammon                  Germany
# Klaus Scharioth              Germany
# dtype: object

# %% [markdown]
# ##### The two most important methods to deal with duplicates are `duplicated` (that will tell you which values are duplicates) and `drop_duplicates` (which will just get rid of duplicates)

# %%
ambassadors.duplicated()
# Out:
# Gérard Araud          False
# Kim Darroch           False
# Peter Westmacott       True
# Armando Varricchio    False
# Peter Wittig          False
# Peter Ammon            True
# Klaus Scharioth        True
# dtype: bool

# %% [markdown]
# ##### In this case *duplicated* didn't consider *'Kim Darroch'*, the first instance of the United Kingdom or *'Peter Wittig'* as duplicates. That's because, by default, it'll consider the first occurrence of the value as not-duplicate. You can change this behavior with the *keep* parameter

# %%
ambassadors.duplicated(keep = 'last')
# Out:
# Gérard Araud          False
# Kim Darroch            True
# Peter Westmacott      False
# Armando Varricchio    False
# Peter Wittig           True
# Peter Ammon            True
# Klaus Scharioth       False
# dtype: bool

# %% [markdown]
# ##### In this case, the result is "flipped", *'Kim Darroch'* and *'Peter Wittig'* (the first ambassadors of their countries) are considered duplicates, but *'Peter Westmacott'* and *'Klaus Scharioth'* are not duplicates. You can also choose to mark all of them as duplicates with *keep=False*

# %%
ambassadors.duplicated(keep = False)
# Out:
# Gérard Araud          False
# Kim Darroch            True
# Peter Westmacott       True
# Armando Varricchio    False
# Peter Wittig           True
# Peter Ammon            True
# Klaus Scharioth        True
# dtype: bool

# %% [markdown]
# ##### A similar method is **drop_duplicates**, which just excludes the duplicated values and also accepts the **keep** parameter

# %%
ambassadors.drop_duplicates()
# Out:
# Gérard Araud                  France
# Kim Darroch           United Kingdom
# Armando Varricchio             Italy
# Peter Wittig                 Germany
# dtype: object

# %%
ambassadors.drop_duplicates(keep = 'last')
# Out:
# Gérard Araud                  France
# Peter Westmacott      United Kingdom
# Armando Varricchio             Italy
# Klaus Scharioth              Germany
# dtype: object

# %%
ambassadors.drop_duplicates(keep = False)
# Out:
# Gérard Araud          France
# Armando Varricchio     Italy
# dtype: object

# %% [markdown]
# #### **Duplicates in DataFrames**

# %% [markdown]
# ##### Duplicates in a DataFrame happen at "row" level. Two rows with exactly the same values are considered to be duplicates.

# %%
players = pd.DataFrame({
    'Name': [
        'Kobe Bryant',
        'LeBron James',
        'Kobe Bryant',
        'Carmelo Anthony',
        'Kobe Bryant'
    ],
    'Pos': [
        'SG',
        'SF',
        'SG',
        'SF',
        'SF'
    ]
})
players
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 2      Kobe Bryant  SG
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %%
players.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# ##### Again, conceptually, "duplicated" means "all the column values should be duplicates". We can customize this with the **subset** parameter

# %%
players.duplicated(subset = ['Name'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
players.duplicated(subset = ['Name'], keep = 'last')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
players.drop_duplicates()
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %%
players.drop_duplicates(subset = ['Name'])
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF

# %%
players.drop_duplicates(subset = ['Name'], keep = 'last')
# Out:
#               Name Pos
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %% [markdown]
# ### **Text Handling**

# %% [markdown]
# #### **Splitting columns**

# %%
df = pd.DataFrame({
    'Data' : [
        '1987_M_US _1',
        '1990?_M_UK_1',
        '1992_F_US_2',
        '1970?_M_   IT_1',
        '1985_F_I  T_2'
    ]
})

df
# Out:
#               Data
# 0     1987_M_US _1
# 1     1990?_M_UK_1
# 2      1992_F_US_2
# 3  1970?_M_   IT_1
# 4    1985_F_I  T_2

# %% [markdown]
# ##### The single columns represent the values "year, Sex, Country and number of children", but it's all been grouped in the same column and separated by an underscore. Pandas has a convenient method named **split** that we can use in these situations

# %%
df['Data'].str.split('_')
# Out:
# 0       [1987, M, US , 1]
# 1       [1990?, M, UK, 1]
# 2        [1992, F, US, 2]
# 3    [1970?, M,    IT, 1]
# 4      [1985, F, I  T, 2]
# Name: Data, dtype: object

# %%
df['Data'].str.split('_', expand = True)   #expand creates a DataFrame
# Out:
#        0  1      2  3
# 0   1987  M    US   1
# 1  1990?  M     UK  1
# 2   1992  F     US  2
# 3  1970?  M     IT  1
# 4   1985  F   I  T  2

# %%
df = df['Data'].str.split('_', expand = True)

# %%
df.columns = ['Year', 'Sex', 'Country', 'No. Children']

# %%
df
# Out:
#     Year Sex Country No Children
# 0   1987   M     US            1
# 1  1990?   M      UK           1
# 2   1992   F      US           2
# 3  1970?   M      IT           1
# 4   1985   F    I  T           2

# %% [markdown]
# ##### You can also check which columns contain a given value with the **contains** method

# %%
df['Year'].str.contains('\?')
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Year, dtype: bool

# %% [markdown]
# ##### **contains** takes a regex/pattern as first value, so we need to escape the **?** symbol as it has a special meaning for these patterns. Regular letters don't need escaping

# %%
df['Country'].str.contains('U')
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Country, dtype: bool

# %% [markdown]
# ##### Removing blank spaces (like in 'US ' or 'I T' can be achieved with **strip** (**lstrip** and **rstrip** also exist) or just **replace**

# %%
df['Country'].str.strip()
# Out:
# 0      US
# 1      UK
# 2      US
# 3      IT
# 4    I  T
# Name: Country, dtype: object

# %%
df['Country'].str.replace(' ','')
# Out:
# 0    US
# 1    UK
# 2    US
# 3    IT
# 4    IT
# Name: Country, dtype: object

# %% [markdown]
# ##### **replace** and **contains** take regex patterns, which can make it easier to replace values in bulk

# %%
df['Year'].str.replace(r'(?P<year>\d{4})\?', lambda m: m.group('year')
# Out:
#   Cell In[28], line 1
#     df['Year'].str.replace(r'(?P<year>\d{4})\?', lambda m: m.group('year')
#                                                                           ^
# SyntaxError: incomplete input

# %% [markdown]
# #####  string/text-related operations are applied over the **str** attribute of the series. That's because they have a special place in Series handling

# %% [markdown]
# ---

# %% [markdown]
# ### **Additional Practice**

# %%
df = pd.read_csv('covid_19_clean_complete.csv')

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.tail()
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
df.size
# Out:
# 490680

# %%
df.shape
# Out:
# (49068, 10)

# %%
deaths = df.Deaths > 100000
deaths
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49063    False
# 49064    False
# 49065    False
# 49066    False
# 49067    False
# Name: Deaths, Length: 49068, dtype: bool

# %%
df[deaths]
# Out:
#       Province/State Country/Region   Lat   Long        Date  Confirmed  \
# 33109            NaN             US  40.0 -100.0  2020-05-27    1707445
# 33370            NaN             US  40.0 -100.0  2020-05-28    1730260
# 33631            NaN             US  40.0 -100.0  2020-05-29    1754764
# 33892            NaN             US  40.0 -100.0  2020-05-30    1779214
# 34153            NaN             US  40.0 -100.0  2020-05-31    1799124
# ...              ...            ...   ...    ...         ...        ...
# 47986            NaN             US  40.0 -100.0  2020-07-23    4038816
# 48247            NaN             US  40.0 -100.0  2020-07-24    4112531
# 48508            NaN             US  40.0 -100.0  2020-07-25    4178970
# 48769            NaN             US  40.0 -100.0  2020-07-26    4233923
# 49030            NaN             US  40.0 -100.0  2020-07-27    4290259
#
#        Deaths  Recovered   Active WHO Region
# 33109  101461     391508  1214476   Americas
# ...

# %%
deaths = df[df.Deaths > 100000]
deaths
# Out:
#       Province/State Country/Region   Lat   Long        Date  Confirmed  \
# 33109            NaN             US  40.0 -100.0  2020-05-27    1707445
# 33370            NaN             US  40.0 -100.0  2020-05-28    1730260
# 33631            NaN             US  40.0 -100.0  2020-05-29    1754764
# 33892            NaN             US  40.0 -100.0  2020-05-30    1779214
# 34153            NaN             US  40.0 -100.0  2020-05-31    1799124
# ...              ...            ...   ...    ...         ...        ...
# 47986            NaN             US  40.0 -100.0  2020-07-23    4038816
# 48247            NaN             US  40.0 -100.0  2020-07-24    4112531
# 48508            NaN             US  40.0 -100.0  2020-07-25    4178970
# 48769            NaN             US  40.0 -100.0  2020-07-26    4233923
# 49030            NaN             US  40.0 -100.0  2020-07-27    4290259
#
#        Deaths  Recovered   Active WHO Region
# 33109  101461     391508  1214476   Americas
# ...

# %% [markdown]
# ##### Show all the rows and columns of a dataframe where Deaths > 10000

# %%
from IPython.display import display
with pd.option_context('display.max_rows', 100):
    display(df[df.Deaths > 10000])
# Out:
#       Province/State  Country/Region        Lat        Long        Date  \
# 17361            NaN           Italy  41.871940   12.567380  2020-03-28
# 17622            NaN           Italy  41.871940   12.567380  2020-03-29
# 17883            NaN           Italy  41.871940   12.567380  2020-03-30
# 18144            NaN           Italy  41.871940   12.567380  2020-03-31
# 18405            NaN           Italy  41.871940   12.567380  2020-04-01
# ...              ...             ...        ...         ...         ...
# 48986            NaN            Peru  -9.190000  -75.015200  2020-07-27
# 48992            NaN          Russia  61.524010  105.318756  2020-07-27
# 49006            NaN           Spain  40.463667   -3.749220  2020-07-27
# 49028            NaN  United Kingdom  55.378100   -3.436000  2020-07-27
# 49030            NaN              US  40.000000 -100.000000  2020-07-27
#
#        Confirmed  Deaths  Recovered   Active WHO Region
# ...

# %%
df.drop(columns = ['Confirmed'], inplace = True)

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Deaths  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22       0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22       0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22       0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22       0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22       0
#
#    Recovered  Active             WHO Region
# 0          0       0  Eastern Mediterranean
# 1          0       0                 Europe
# 2          0       0                 Africa
# 3          0       0                 Europe
# 4          0       0                 Africa

# %%
df.sort_values('Deaths', ascending = False).head(10)
# Out:
#       Province/State Country/Region   Lat   Long        Date  Deaths  \
# 49030            NaN             US  40.0 -100.0  2020-07-27  148011
# 48769            NaN             US  40.0 -100.0  2020-07-26  146935
# 48508            NaN             US  40.0 -100.0  2020-07-25  146465
# 48247            NaN             US  40.0 -100.0  2020-07-24  145560
# 47986            NaN             US  40.0 -100.0  2020-07-23  144430
# 47725            NaN             US  40.0 -100.0  2020-07-22  143316
# 47464            NaN             US  40.0 -100.0  2020-07-21  142121
# 47203            NaN             US  40.0 -100.0  2020-07-20  141025
# 46942            NaN             US  40.0 -100.0  2020-07-19  140534
# 46681            NaN             US  40.0 -100.0  2020-07-18  140119
#
#        Recovered   Active WHO Region
# 49030    1325804  2816444   Americas
# 48769    1297863  2789125   Americas
# 48508    1279414  2753091   Americas
# 48247    1261624  2705347   Americas
# ...

# %% [markdown]
# ##### `sort_values()` - sorting the rows of a dataframe using column values

# %%
df.sort_values('Deaths').head(10)
# Out:
#          Province/State Country/Region        Lat        Long        Date  \
# 0                   NaN    Afghanistan  33.939110   67.709953  2020-01-22
# 14989         St Martin         France  18.070800  -63.050100  2020-03-19
# 14988  Saint Barthelemy         France  17.900000  -62.833300  2020-03-19
# 14987           Reunion         France -21.115100   55.536400  2020-03-19
# 14986     New Caledonia         France -20.904305  165.618042  2020-03-19
# 14985           Mayotte         France -12.827500   45.166244  2020-03-19
# 14984        Guadeloupe         France  16.265000  -61.551000  2020-03-19
# 14983  French Polynesia         France -17.679700  149.406800  2020-03-19
# 14992               NaN          Gabon  -0.803700   11.609400  2020-03-19
# 14982     French Guiana         France   3.933900  -53.125800  2020-03-19
#
#        Deaths  Recovered  Active             WHO Region
# 0           0          0       0  Eastern Mediterranean
# ...

# %%
df.loc[45000 : 45008]
# Out:
#          Province/State Country/Region        Lat        Long        Date  \
# 45000           Mayotte         France -12.827500   45.166244  2020-07-12
# 45001     New Caledonia         France -20.904305  165.618042  2020-07-12
# 45002           Reunion         France -21.115100   55.536400  2020-07-12
# 45003  Saint Barthelemy         France  17.900000  -62.833300  2020-07-12
# 45004         St Martin         France  18.070800  -63.050100  2020-07-12
# 45005        Martinique         France  14.641500  -61.024200  2020-07-12
# 45006               NaN         France  46.227600    2.213700  2020-07-12
# 45007               NaN          Gabon  -0.803700   11.609400  2020-07-12
# 45008               NaN         Gambia  13.443200  -15.310100  2020-07-12
#
#         Deaths  Recovered  Active WHO Region
# 45000     37.0       2480     194     Europe
# 45001      0.0         21       0     Europe
# 45002      3.0        472     118     Europe
# 45003      0.0          6       0     Europe
# ...

# %% [markdown]
# ##### The `.at` method can be used to modify a specific value with a dataframe

# %%
df.at[45006, 'Deaths'] = (df.at[45005, 'Deaths'] + df.at[45006, 'Deaths']) / 2

# %%
df.iloc[45000 : 45008]
# Out:
#          Province/State Country/Region        Lat        Long        Date  \
# 45000           Mayotte         France -12.827500   45.166244  2020-07-12
# 45001     New Caledonia         France -20.904305  165.618042  2020-07-12
# 45002           Reunion         France -21.115100   55.536400  2020-07-12
# 45003  Saint Barthelemy         France  17.900000  -62.833300  2020-07-12
# 45004         St Martin         France  18.070800  -63.050100  2020-07-12
# 45005        Martinique         France  14.641500  -61.024200  2020-07-12
# 45006               NaN         France  46.227600    2.213700  2020-07-12
# 45007               NaN          Gabon  -0.803700   11.609400  2020-07-12
#
#         Deaths  Recovered  Active WHO Region
# 45000     37.0       2480     194     Europe
# 45001      0.0         21       0     Europe
# 45002      3.0        472     118     Europe
# 45003      0.0          6       0     Europe
# 45004      3.0         37       3     Europe
# ...

# %% [markdown]
# #### Renaming a column with `rename()` method

# %%
#renmaing Date column to date
df.rename(columns = {'Date' : 'date'}, inplace = True)

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        date  Deaths  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22     0.0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22     0.0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22     0.0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22     0.0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22     0.0
#
#    Recovered  Active             WHO Region
# 0          0       0  Eastern Mediterranean
# 1          0       0                 Europe
# 2          0       0                 Africa
# 3          0       0                 Europe
# 4          0       0                 Africa

# %% [markdown]
# ### **Working with dates**

# %%
df.date
# Out:
# 0        2020-01-22
# 1        2020-01-22
# 2        2020-01-22
# 3        2020-01-22
# 4        2020-01-22
#             ...
# 49063    2020-07-27
# 49064    2020-07-27
# 49065    2020-07-27
# 49066    2020-07-27
# 49067    2020-07-27
# Name: date, Length: 49068, dtype: object

# %% [markdown]
# ##### As the dtype of date is object, Pandas does not know that it is date, so let's convert it to date.

# %%
df['date'] = pd.to_datetime(df.date)
df['date']
# Out:
# 0       2020-01-22
# 1       2020-01-22
# 2       2020-01-22
# 3       2020-01-22
# 4       2020-01-22
#            ...
# 49063   2020-07-27
# 49064   2020-07-27
# 49065   2020-07-27
# 49066   2020-07-27
# 49067   2020-07-27
# Name: date, Length: 49068, dtype: datetime64[ns]

# %% [markdown]
# ##### Hence, the dtype has been now chnaged to datetime.

# %% [markdown]
# ##### We can extract diff parts of the data into separate columns using the `DatetimeIndex` class

# %%
df['year'] = pd.DatetimeIndex(df.date).year
df['month'] = pd.DatetimeIndex(df.date).month
df['day'] = pd.DatetimeIndex(df.date).day
df['weekday'] = pd.DatetimeIndex(df.date).weekday

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long       date  \
# 0                NaN            Afghanistan  33.939110  67.709953 2020-01-22
# 1                NaN                Albania  41.153300  20.168300 2020-01-22
# 2                NaN                Algeria  28.033900   1.659600 2020-01-22
# 3                NaN                Andorra  42.506300   1.521800 2020-01-22
# 4                NaN                 Angola -11.202700  17.873900 2020-01-22
# ...              ...                    ...        ...        ...        ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100 2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388 2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300 2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100 2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600 2020-07-27
#
# ...

# %% [markdown]
# ---

# %%
#Query the rows for May
df_may = df[df.month == 5]
df_may
# Out:
#       Province/State         Country/Region        Lat       Long       date  \
# 26100            NaN            Afghanistan  33.939110  67.709953 2020-05-01
# 26101            NaN                Albania  41.153300  20.168300 2020-05-01
# 26102            NaN                Algeria  28.033900   1.659600 2020-05-01
# 26103            NaN                Andorra  42.506300   1.521800 2020-05-01
# 26104            NaN                 Angola -11.202700  17.873900 2020-05-01
# ...              ...                    ...        ...        ...        ...
# 34186            NaN  Sao Tome and Principe   0.186400   6.613100 2020-05-31
# 34187            NaN                  Yemen  15.552727  48.516388 2020-05-31
# 34188            NaN                Comoros -11.645500  43.333300 2020-05-31
# 34189            NaN             Tajikistan  38.861000  71.276100 2020-05-31
# 34190            NaN                Lesotho -29.610000  28.233600 2020-05-31
#
# ...

# %%
#Extract subset of columns to be aggregated
df_may_metrices = df_may[['Deaths','Recovered','Active']]
df_may_metrices
# Out:
#        Deaths  Recovered  Active
# 26100    68.0        310    1957
# 26101    31.0        488     263
# 26102   453.0       1821    1880
# 26103    43.0        468     234
# 26104     2.0         11      17
# ...       ...        ...     ...
# 34186    12.0         68     403
# 34187    80.0         14     229
# 34188     2.0         26      78
# 34189    47.0       2004    1879
# 34190     0.0          1       1
#
# [8091 rows x 3 columns]

# %%
#Get the column-wise sum
df_may_totals = df_may_metrices.sum()
df_may_totals
# Out:
# Deaths        9609604.0
# Recovered    52876838.0
# Active       82503957.0
# dtype: float64

# %%
type(df_may_totals)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##### The operations 3 operations starting can be combined into a single statement.

# %%
df[df.month == 5][['Deaths','Recovered','Active']].sum()
# Out:
# Deaths        9609604.0
# Recovered    52876838.0
# Active       82503957.0
# dtype: float64

# %% [markdown]
# ---

# %%
#Overall avg
df.Deaths.mean()
# Out:
# 883.8704896775903

# %%
#avg for sundays
df[df.weekday == 6].Deaths.mean()
# Out:
# 903.019582801192

# %% [markdown]
# ### **Grouping and aggregation**

# %% [markdown]
# ##### Using `groupby()` function to summarzie the daywise data and create a new dataframe with month-wise data.

# %% [markdown]
# #### **Eg 1**

# %%
#for each month the rows are collected in a single group
df.groupby('month')

# %%
df.groupby('month')[['Deaths','Recovered','Active']]

# %%
df.groupby('month')[['Deaths','Recovered','Active']].sum()
# Out:
#              Deaths  Recovered     Active
# month
# 1      8.890000e+02        838      36807
# 2      4.687500e+04     363669    1252893
# 3      3.976010e+05    2644372    5960842
# 4      4.311214e+06   15944020   43136428
# 5      9.609604e+06   52876838   82503957
# 6      1.330905e+07  116984268  116232466
# 7      1.569452e+07  199594224  147591957

# %% [markdown]
# #### **Eg 2**

# %%
df.groupby('weekday')[['Deaths','Recovered','Active']].mean()
# Out:
#              Deaths    Recovered       Active
# weekday
# 0        915.911026  8443.224918  8428.604654
# 1        869.846771  7562.756410  7933.930150
# 2        852.501490  7479.324535  7765.065276
# 3        867.707109  7684.363417  7902.939833
# 4        882.483042  7885.971761  8050.709947
# 5        895.105009  8093.531999  8179.505747
# 6        903.019583  8247.748829  8328.730098

# %% [markdown]
# ##### Calculate the cumulative sum of deaths, recovered and active for each row using the `cumsum()` method. Lets's add 3 new columns `total_deaths`, `total_recovered`, `total_active`.

# %%
df['total_deaths'] = df.Deaths.cumsum()

# %%
df['total_recovered'] = df.Recovered.cumsum()

# %%
df['total_active'] = df.Active.cumsum()

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long       date  \
# 0                NaN            Afghanistan  33.939110  67.709953 2020-01-22
# 1                NaN                Albania  41.153300  20.168300 2020-01-22
# 2                NaN                Algeria  28.033900   1.659600 2020-01-22
# 3                NaN                Andorra  42.506300   1.521800 2020-01-22
# 4                NaN                 Angola -11.202700  17.873900 2020-01-22
# ...              ...                    ...        ...        ...        ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100 2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388 2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300 2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100 2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600 2020-07-27
#
# ...

# %% [markdown]
# #### There are also `cummax()`, `cummin()` methods

# %% [markdown]
# ### **Merging data from multiple resources**

# %%
covid_df = pd.read_csv('covid_19_clean_complete.csv')

# %%
countries_df = pd.read_csv('countries of the world.csv')

# %%
countries_df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
countries_df[countries_df.Country == 'Albania']
# Out:
# Empty DataFrame
# Columns: [Country, Region, Population, Area (sq. mi.), Pop. Density (per sq. mi.), Coastline (coast/area ratio), Net migration, Infant mortality (per 1000 births), GDP ($ per capita), Literacy (%), Phones (per 1000), Arable (%), Crops (%), Other (%), Climate, Birthrate, Deathrate, Agriculture, Industry, Service]
# Index: []

# %%
covid_df['Country'] = 'Albania'

# %%
covid_df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %% [markdown]
# ##### Adding the columns from countries_df into df using the `merge()` method

# %%
merged_df = covid_df.merge(countries_df, on = 'Country')
merged_df
# Out:
# Empty DataFrame
# Columns: [Province/State, Country/Region, Lat, Long, Date, Confirmed, Deaths, Recovered, Active, WHO Region, Country, Region, Population, Area (sq. mi.), Pop. Density (per sq. mi.), Coastline (coast/area ratio), Net migration, Infant mortality (per 1000 births), GDP ($ per capita), Literacy (%), Phones (per 1000), Arable (%), Crops (%), Other (%), Climate, Birthrate, Deathrate, Agriculture, Industry, Service]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# ##### The countires data for Albania is appended to each row within covid_df dataframe

# %% [markdown]
# ##### To save the data to a file use `to_csv()` method. If file already exists it will overwrite the previous data. As the pandas treat index also as a column so use `index = None / index = False` to turn off this behaviour.

# %% [markdown]
# ### **Basic Plotting with Pandas**

# %% [markdown]
# ##### While we typically use libraries like `matplotlib` or `seaborn` to plot graphs with Jupyter notebook, Pandas DataFrames and Series also provide a handy `plot()` method for quick and easy plotting.

# %% [markdown]
# ##### Let's plot line graph showing how the no. of daily cases varies over time using the `plot()` method of a Pandas Series.

# %%
countries_df.Population.plot();

# %%
df = countries_df.set_index('Country', inplace = True)

# %%
countries_df
# Out:
#                                               Region  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
# ...                                              ...         ...
# West Bank        NEAR EAST                               2460492
# Western Sahara   NORTHERN AFRICA                          273008
# Yemen            NEAR EAST                              21456188
# Zambia           SUB-SAHARAN AFRICA                     11502010
# Zimbabwe         SUB-SAHARAN AFRICA                     12236805
#
#                  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                       48,0
# ...

# %%
covid_df.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# WHO Region         object
# dtype: object

# %%
covid_df.Recovered.plot()
covid_df.Deaths.plot();

# %%
death_rate = covid_df.Deaths / covid_df.Active

# %%
death_rate.plot(title = 'Death Rate')
# Out:
# <Axes: title={'center': 'Death Rate'}>
